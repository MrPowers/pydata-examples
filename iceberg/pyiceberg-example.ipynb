# %% [markdown]
# # PyIceberg Example

# %%
from pyiceberg.catalog import load_catalog
import pyarrow.parquet as pq
import pyarrow.dataset as ds
import polars as pl

# %%
# Create a temporary location for Iceberg
# !mkdir /tmp/warehouse
# Out:
# mkdir: /tmp/warehouse: File exists

# %%
# set up the catalog
warehouse_path = "/tmp/warehouse"
catalog = load_catalog(
    "default",
    **{
        'type': 'sql',
        "uri": f"sqlite:///{warehouse_path}/pyiceberg_catalog.db",
        "warehouse": f"file://{warehouse_path}",
    },
)

# %%
df = pq.read_table("/Users/matthewpowers/data/tpch_sf1/nation.parquet")

# %%
# create a new iceberg table
catalog.create_namespace("default")

table = catalog.create_table(
    "default.nation",
    schema=df.schema,
)

# %%
# Append the dataframe to the table
table.append(df)

# %%
# check length of table
len(table.scan().to_arrow())
# Out:
# 25

# %% [markdown]
# ## Read Iceberg table into Polars via Arrow

# %%
# Load the table (namespace.table_name)
table = catalog.load_table("default.nation")

# Scan and load as a PyArrow table
arrow_table = table.scan().to_arrow()

# Convert to Polars DataFrame
df = pl.from_arrow(arrow_table)

print(df.head())
# Out:
# shape: (5, 4)
# ┌─────────────┬───────────┬─────────────┬─────────────────────────────────┐
# │ n_nationkey ┆ n_name    ┆ n_regionkey ┆ n_comment                       │
# │ ---         ┆ ---       ┆ ---         ┆ ---                             │
# │ i64         ┆ str       ┆ i64         ┆ str                             │
# ╞═════════════╪═══════════╪═════════════╪═════════════════════════════════╡
# │ 0           ┆ ALGERIA   ┆ 0           ┆  haggle. carefully final depos… │
# │ 1           ┆ ARGENTINA ┆ 1           ┆ al foxes promise slyly accordi… │
# │ 2           ┆ BRAZIL    ┆ 1           ┆ y alongside of the pending dep… │
# │ 3           ┆ CANADA    ┆ 1           ┆ eas hang ironic, silent packag… │
# │ 4           ┆ EGYPT     ┆ 4           ┆ y above the carefully unusual … │
# └─────────────┴───────────┴─────────────┴─────────────────────────────────┘

# %% [markdown]
# ## Read Iceberg table into Polars via native reader

# %%
table_path = "/tmp/warehouse/default/nation"  # path to the Iceberg table folder

lazy_df = pl.scan_iceberg(
    source=table_path,
    reader_override="native"
)

# Collect into a Polars DataFrame
df = lazy_df.collect()

print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 9
#       3 lazy_df = pl.scan_iceberg(
#       4     source=table_path,
#       5     reader_override="native"
#       6 )
#       8 # Collect into a Polars DataFrame
# ----> 9 df = lazy_df.collect()
#      11 print(df.head())
#
# File ~/Documents/code/my_apps/pydata-examples/.venv/lib/python3.12/site-packages/polars/_utils/deprecation.py:97, in deprecate_streaming_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      93         kwargs["engine"] = "in-memory"
#      95     del kwargs["streaming"]
# ---> 97 return function(*args, **kwargs)
#
# File ~/Documents/code/my_apps/pydata-examples/.venv/lib/python3.12/site-packages/polars/lazyframe/opt_flags.py:328, in forward_old_opt_flags.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325         optflags = cb(optflags, kwargs.pop(key))  # type: ignore[no-untyped-call,unused-ignore]
#     327 kwargs["optimizations"] = optflags
# --> 328 return function(*args, **kwargs)
#
# File ~/Documents/code/my_apps/pydata-examples/.venv/lib/python3.12/site-packages/polars/lazyframe/frame.py:2422, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, engine, background, optimizations, **_kwargs)
#    2420 # Only for testing purposes
#    2421 callback = _kwargs.get("post_opt_callback", callback)
# -> 2422 return wrap_df(ldf.collect(engine, callback))
#
# File ~/Documents/code/my_apps/pydata-examples/.venv/lib/python3.12/site-packages/polars/io/iceberg/dataset.py:66, in IcebergDataset.schema(self)
#      64 def schema(self) -> pa.schema:
#      65     """Fetch the schema of the table."""
# ---> 66     return self.arrow_schema()
#
# File ~/Documents/code/my_apps/pydata-examples/.venv/lib/python3.12/site-packages/polars/io/iceberg/dataset.py:72, in IcebergDataset.arrow_schema(self)
#      69 """Fetch the arrow schema of the table."""
#      70 from pyiceberg.io.pyarrow import schema_to_pyarrow
# ---> 72 return schema_to_pyarrow(self.table().schema())
#
# File ~/Documents/code/my_apps/pydata-examples/.venv/lib/python3.12/site-packages/polars/io/iceberg/dataset.py:417, in IcebergDataset.table(self)
#     413         eprint(f"IcebergDataset: construct table from {self._metadata_path = }")
#     415     from pyiceberg.table import StaticTable
# --> 417     self._table = StaticTable.from_metadata(
#     418         metadata_location=self._metadata_path,
#     419         properties=self._iceberg_storage_properties or {},
#     420     )
#     422 return self._table
#
# File ~/Documents/code/my_apps/pydata-examples/.venv/lib/python3.12/site-packages/pyiceberg/table/__init__.py:1592, in StaticTable.from_metadata(cls, metadata_location, properties)
#    1589 @classmethod
#    1590 def from_metadata(cls, metadata_location: str, properties: Properties = EMPTY_DICT) -> StaticTable:
#    1591     if not metadata_location.endswith(".metadata.json"):
# -> 1592         metadata_location = StaticTable._metadata_location_from_version_hint(metadata_location, properties)
#    1594     io = load_file_io(properties=properties, location=metadata_location)
#    1595     file = io.new_input(metadata_location)
#
# File ~/Documents/code/my_apps/pydata-examples/.venv/lib/python3.12/site-packages/pyiceberg/table/__init__.py:1579, in StaticTable._metadata_location_from_version_hint(cls, metadata_location, properties)
#    1576 io = load_file_io(properties=properties, location=version_hint_location)
#    1577 file = io.new_input(version_hint_location)
# -> 1579 with file.open() as stream:
#    1580     content = stream.read().decode("utf-8")
#    1582 if content.endswith(".metadata.json"):
#
# File ~/Documents/code/my_apps/pydata-examples/.venv/lib/python3.12/site-packages/pyiceberg/io/pyarrow.py:333, in PyArrowFile.open(self, seekable)
#     331 try:
#     332     if seekable:
# --> 333         input_file = self._filesystem.open_input_file(self._path)
#     334     else:
#     335         input_file = self._filesystem.open_input_stream(self._path, buffer_size=self._buffer_size)
#
# File ~/Documents/code/my_apps/pydata-examples/.venv/lib/python3.12/site-packages/pyarrow/_fs.pyx:815, in pyarrow._fs.FileSystem.open_input_file()
#
# File ~/Documents/code/my_apps/pydata-examples/.venv/lib/python3.12/site-packages/pyarrow/error.pxi:155, in pyarrow.lib.pyarrow_internal_check_status()
#
# File ~/Documents/code/my_apps/pydata-examples/.venv/lib/python3.12/site-packages/pyarrow/error.pxi:92, in pyarrow.lib.check_status()
#
# FileNotFoundError: [Errno 2] Failed to open local file '/tmp/warehouse/default/nation/metadata/version-hint.text'. Detail: [errno 2] No such file or directory
#
# This error occurred with the following context stack:
# 	[1] 'python dataset scan'
# 	[2] 'sink'
